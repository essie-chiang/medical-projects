# %%
from train import UnetModel
from data_process import preprocess
import os

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
no_train, no_test,lower_train, lower_test,full_train,full_test=preprocess()
# Out:
# 892
# 892
# 892
# (892, 240, 240)
# (892, 240, 240, 1)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
unet = UnetModel(layers=3)

# %%
model = unet.get_model()
# Out:
# get u3 model
# WARNING:tensorflow:From /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING: Logging before flag parsing goes to stderr.
# W0327 08:14:20.838985 139941028960064 deprecation.py:323] From /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 240, 240, 1)  0
# ...

# %%
model.fit([no_train, lower_train], full_train,
epochs=10,
batch_size=2,
validation_data=([no_test, lower_test], full_test))
# Out:
# Train on 802 samples, validate on 90 samples
# WARNING:tensorflow:From /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# W0327 08:14:26.147687 139941028960064 deprecation.py:323] From /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 802/802 [==============================] - 36s 45ms/sample - loss: 0.0778 - val_loss: 0.0757
# Epoch 2/10
# 802/802 [==============================] - 32s 40ms/sample - loss: 0.0737 - val_loss: 0.0751
# Epoch 3/10
# 802/802 [==============================] - 32s 40ms/sample - loss: 0.0730 - val_loss: 0.0729
# Epoch 4/10
# ...

# %%
unet = UnetModel(layers=2)
model = unet.get_model()
# Out:
# get u2 model
# concat 1: Tensor("add_8/add:0", shape=(?, 240, 240, 24), dtype=float32)
# Tensor("max_pooling2d_3/MaxPool:0", shape=(?, 120, 120, 24), dtype=float32)
# concat 2: Tensor("add_9/add:0", shape=(?, 120, 120, 48), dtype=float32)
# Tensor("max_pooling2d_4/MaxPool:0", shape=(?, 60, 60, 48), dtype=float32)
# Tensor("up_sampling2d_3/ResizeNearestNeighbor:0", shape=(?, 120, 120, 96), dtype=float32)
# Tensor("up_sampling2d_4/ResizeNearestNeighbor:0", shape=(?, 240, 240, 48), dtype=float32)
# Tensor("add_12/add:0", shape=(?, 240, 240, 24), dtype=float32)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 240, 240, 1)  0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 240, 240, 1)  0
# ...

# %%
model.fit([no_train, lower_train], full_train,
epochs=10,
batch_size=2,
validation_data=([no_test, lower_test], full_test))
# Out:
# Train on 802 samples, validate on 90 samples
# Epoch 1/10
# 802/802 [==============================] - 26s 33ms/sample - loss: 0.0986 - acc: 0.3088 - psnr: 19.3072 - val_loss: 0.0977 - val_acc: 0.3119 - val_psnr: 19.2845
# Epoch 2/10
# 802/802 [==============================] - 26s 32ms/sample - loss: 0.0973 - acc: 0.3088 - psnr: 19.3551 - val_loss: 0.0977 - val_acc: 0.3119 - val_psnr: 19.2955
# Epoch 3/10
# 802/802 [==============================] - 26s 32ms/sample - loss: 0.0973 - acc: 0.3088 - psnr: 19.3517 - val_loss: 0.0977 - val_acc: 0.3119 - val_psnr: 19.2615
# Epoch 4/10
# 802/802 [==============================] - 26s 32ms/sample - loss: 0.0973 - acc: 0.3088 - psnr: 19.3650 - val_loss: 0.0977 - val_acc: 0.3119 - val_psnr: 19.2956
# Epoch 5/10
# 802/802 [==============================] - 26s 32ms/sample - loss: 0.0973 - acc: 0.3088 - psnr: 19.3538 - val_loss: 0.0977 - val_acc: 0.3119 - val_psnr: 19.3179
# Epoch 6/10
# ...
